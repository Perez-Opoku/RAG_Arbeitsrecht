# %%
import chromadb


client = chromadb.PersistentClient(path="/Users/perezopoku/Desktop/Programme/Persönlcihe Projekte/RAG/chroma_db")

collection = client.get_collection("quickstart")
# alles auslesen
data = collection.get(include=["embeddings", "metadatas", "documents"])

embeddings = data["embeddings"]       # Liste von Embedding-Vektoren
documents = data["documents"]         # Originaltexte (falls vorhanden)
metadatas = data["metadatas"]         # ggf. Titel, Tags etc.
ids = data["ids"]

# %%
pip install polars
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import polars as pl
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

# %%
print(data["embeddings"].shape)
# Out:
# (332, 1024)

# %%
print(data["documents"][:5])  # Erste 5 Dokumente anzeigen
# Out:
# ['[CLS] gesetz zur regelung eines allgemeinen mindestlohns ( 1 ) jede arbeitnehmerin und jeder arbeitnehmer hat anspruch auf zahlung eines arbeitsentgelts mindestens in hohe des mindestlohns durch den arbeitgeber. ( 2 ) die hohe des mindestlohns betragt ab dem 1. oktober 2022 brutto 12 euro je zeitstunde. die hohe des mindestlohns kann auf vorschlag einer standigen kommission der tarifpartner ( mindestlohnkommission ) durch rechtsverordnung der bundesregierung geandert werden. ( 3 ) die regelungen des arbeitnehmer - entsendegesetzes, des arbeitnehmeruberlassungsgesetzes und der auf ihrer grundlage erlassenen rechtsverordnungen gehen den regelungen dieses gesetzes vor, soweit die hohe der auf ihrer grundlage festgesetzten branchenmindestlohne die hohe des mindestlohns nicht unterschreitet. ( 1 ) der arbeitgeber ist verpflichtet, der arbeitnehmerin oder dem arbeitnehmer den mindestlohn 1. zum zeitpunkt der vereinbarten falligkeit, 2. spatestens am letzten bankarbeitstag ( frankfurt am 
# ...

# %%
print(len(data["ids"]))
# Out:
# 332

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "id": ids,
    "document": documents,
    "metadata": metadatas,
    "embedding": np.array(embeddings).tolist()
})
df.head()
# Out:
#                                      id  \
# 0  eacb1509-89a8-4513-a4cf-c1a7447cc596
# 1  7e28d2a3-5110-4238-9969-30e3bf753934
# 2  26c75ba1-412e-4618-bb9a-8f12aac37f14
# 3  dafc59fc-e0f0-4f63-b0bb-82632f65f5b5
# 4  f8b41091-82e5-40f1-acc5-a8b7cef48728
#
#                                             document  \
# 0  [CLS] gesetz zur regelung eines allgemeinen mi...
# 1  die verwirkung des anspruchs ist ausgeschlosse...
# 2  § 5 absatz 1 satz 3 und 4 und absatz 2 gilt en...
# 3  ( 3 ) die mindestlohnkommission kann spitzenor...
# 4  § 6 absatz 3 sowie die § § 16 bis 19 des schwa...
#
#                                             metadata  \
# 0  {'_node_type': 'TextNode', 'doc_id': '18102029...
# 1  {'ref_doc_id': '18102029-1c4a-4f13-af06-7ff3d9...
# 2  {'source': 'MiLoG.txt', '_node_content': '{"id...
# 3  {'source': 'MiLoG.txt', 'doc_id': '18102029-1c...
# 4  {'_node_type': 'TextNode', 'document_id': '181...
#
#                                            embedding
# ...

# %%
df.embedding.head()
# Out:
# 0    [-0.021340299397706985, 0.06264737993478775, 0...
# 1    [0.013019369915127754, 0.0429564006626606, -0....
# 2    [0.03354838117957115, 0.04470733180642128, 0.0...
# 3    [-0.003843619953840971, 0.0454748198390007, 0....
# 4    [-0.04722394049167633, -0.09488066285848618, 0...
# Name: embedding, dtype: object
